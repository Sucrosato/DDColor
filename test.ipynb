# %%
from basicsr.utils.options import copy_opt_file, dict2str, parse_options

opt, args = parse_options('E:\work\Code\_Remote_Repos\DDColor\experiments\ds-s-coco10k-final\ds-s.yml', is_train=True)
# Out:
# usage: ipykernel_launcher.py [-h] -opt OPT [--launcher {none,pytorch,slurm}]
#                              [--auto_resume] [--debug]
#                              [--local_rank LOCAL_RANK]
#                              [--local-rank LOCAL_RANK]
#                              [--force_yml FORCE_YML [FORCE_YML ...]]
# ipykernel_launcher.py: error: the following arguments are required: -opt
# An exception has occurred, use %tb to see the full traceback.
#
# SystemExit: 2
# c:\ProgramData\miniconda3\envs\rgb\lib\site-packages\IPython\core\interactiveshell.py:3587: UserWarning: To exit: use 'exit', 'quit', or Ctrl-D.
#   warn("To exit: use 'exit', 'quit', or Ctrl-D.", stacklevel=1)
